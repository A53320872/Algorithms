# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    def isSubPath(self, head, root):
        """
        :type head: ListNode
        :type root: TreeNode
        :rtype: bool
        """
        # method2: record all paths
        paths = []
        def preorder(root, path):
            if root == None:
                return ""
            if root.left == None and root.right == None:
                paths.append(path + "->" + str(root.val))
            preorder(root.left, path + "->" + str(root.val))
            preorder(root.right, path + "->" + str(root.val))
        preorder(root, "head")
        # print(paths)
        
        path = ""
        while head:
            path += str(head.val) + "->"
            head = head.next
        path = path[:-2]
        
        for p in paths:
            if path in p:
                return True
        return False
    
        # # method1: find start point, then match the linklist
        # res = [False]
        # def preorder(root, head):
        #     if root == None:
        #         return
        #     if root.val == head.val:
        #         if match(root, head) == True:
        #             res[0] = True
        #     preorder(root.left, head)
        #     preorder(root.right, head)
        # def match(root, head):
        #     if head == None:
        #         return True
        #     if root == None:
        #         return False
        #     if root.val == head.val:
        #         l = match(root.left, head.next)
        #         r = match(root.right, head.next)
        #         if l == True or r == True:
        #             return True
        #     return False
        # preorder(root, head)
        # return res[0]
